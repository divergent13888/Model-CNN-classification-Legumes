# %% [markdown]
# ## Depandecies

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.models import Sequential
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
import sys,os
from importlib import reload

# %% [markdown]
# ## Dataset preprocessing

# %%
# Resize ALL Images adding a padding black and prepare the data 
#read all images 
images_c1 = glob.glob('./Datasets/train/carote/*.jpg')
images_c2 = glob.glob('./Datasets/train/onion/*.jpg')
images_c3 = glob.glob('./Datasets/train/fenouil/*.jpg')
images_c4 = glob.glob('./Datasets/train/potato/*.jpg')
images_c5 = glob.glob('./Datasets/train/tomato/*.jpg')
images_c6 = glob.glob('./Datasets/train/cucumber/*.jpg')
images_c7 = glob.glob('./Datasets/train/choufleur/*.jpg')
images_c8 = glob.glob('./Datasets/train/poischiche/*.jpg')
images_c9 = glob.glob('./Datasets/train/poivron/*.jpg')
images_c10 = glob.glob('./Datasets/train/arichou/*.jpg')
#prepare the input and output arrays
Xtrain = np.zeros((250,128,128,3)) #(image(256*256*3) X, class Y)
Ytrain = np.ones((250))
Xval = np.zeros((100,128,128,3)) #(image(256*256*3) X, class Y)
Yval = np.ones((100))
Xtest = np.zeros((50,128,128,3)) #(image(256*256*3) X, class Y)
Ytest = np.ones((50))

#LOOP THE IMAGES TO RESIZE AND PREPARE THE INPUT AND OUTPUT ARRAYS
j =0
m=0
n=0
for i in range(len(images_c1)*10):
    images = images_c1
    c = 0
    if i >= 40 :
        images = images_c2 
        c = 1
    if i >= 80: 
        images = images_c3
        c = 2
    if i >= 120: 
        images = images_c4
        c = 3
    if i >= 160: 
        images = images_c5
        c = 4
    if i >= 200: 
        images = images_c6
        c = 5
    if i >= 240: 
        images = images_c7
        c = 6
    if i >= 280: 
        images = images_c8
        c = 7
    if i >= 320: 
        images = images_c9
        c = 8
    if i >= 360: 
        images = images_c10
        c = 9
    img = cv2.imread(images[i%40])
    imgF = np.ones((512,512,3),np.uint8)*0
    imgF[0:min(img.shape[0],512),0:min(img.shape[1],512),:] = img[0:min(img.shape[0],512),0:min(img.shape[1],512),:]
    imgF = cv2.resize(imgF, (0, 0), fx = 0.25, fy = 0.25)
    if (i%40) < 25: 
        Xtrain[j] = imgF
        Ytrain[j] = c
        j = j+1
    elif (i%40) < 35 :
        Xval[m] = imgF
        Yval[m] = c
        m = m+1 
    else : 
        Xtest[n] = imgF
        Ytest[n] = c
        n = n + 1

# %%
## NORMALIZE THE DATASETS
print(np.max(Xtrain))
Xtrain = Xtrain / np.max(Xtrain)
Xval = Xval / np.max(Xtrain)
Xtest = Xtest / np.max(Xtrain)
print(np.max(Xtrain))
# Out:
# 255.0
# 1.0

# %%
for i in range(9):
    trainI = Xtrain[i*25]
    ValI   = Xval[i*10]
    testI  = Xtest[i*4]
    #imgtrain = cv2.imshow("i",trainI)
    #cv2.waitKey(0)
    imgval = cv2.imshow("i2",ValI)
    cv2.waitKey(0)
    imgtst = cv2.imshow("i3",testI)
    cv2.waitKey(0)

# %% [markdown]
# ## The model

# %%
output_class = 10
model = Sequential()

model.add(Conv2D(32, (5, 5), activation='relu',padding="same", input_shape=(Xtrain.shape[1], Xtrain.shape[2], Xtrain.shape[3])))
model.add(Conv2D(64, (3, 3),padding="same", activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), padding="same", activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(output_class, activation='softmax'))

model.compile(optimizer='adam',
              loss= tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 512)               67109376
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 67,271,114
# Trainable params: 67,271,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
batch_size  = 60
epochs      = 50

history = model.fit(  Xtrain, Ytrain,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      validation_data = (Xval, Yval))
score = model.evaluate(Xtest, Ytest, verbose=0)

print('Test loss     :', score[0])
print('Test accuracy :', score[1])
# Out:
# Epoch 1/50
# 5/5 [==============================] - 13s 2s/step - loss: 4.2089 - accuracy: 0.1240 - val_loss: 114.3995 - val_accuracy: 0.2000
# Epoch 2/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.9707 - accuracy: 0.3000 - val_loss: 272.6611 - val_accuracy: 0.1700
# Epoch 3/50
# 5/5 [==============================] - 13s 3s/step - loss: 1.6965 - accuracy: 0.3960 - val_loss: 314.1095 - val_accuracy: 0.1900
# Epoch 4/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.4674 - accuracy: 0.3880 - val_loss: 232.2180 - val_accuracy: 0.3000
# Epoch 5/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.1176 - accuracy: 0.5920 - val_loss: 292.1049 - val_accuracy: 0.3400
# Epoch 6/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.8926 - accuracy: 0.6720 - val_loss: 298.1216 - val_accuracy: 0.4100
# Epoch 7/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.7272 - accuracy: 0.7320 - val_loss: 398.0336 - val_accuracy: 0.4200
# Epoch 8/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.5744 - accuracy: 0.8080 - val_loss: 489.8462 - val_accuracy: 0.4000
# Epoch 9/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.5170 - accuracy: 0.8200 - val_loss: 443.8466 - val_accuracy: 0.3600
# Epoch 10/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.3975 - accuracy: 0.8720 - val_loss: 422.3348 - val_accuracy: 0.3900
# Epoch 11/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.3367 - accuracy: 0.8840 - val_loss: 481.2772 - val_accuracy: 0.4600
# Epoch 12/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.3415 - accuracy: 0.8960 - val_loss: 441.5238 - val_accuracy: 0.4600
# Epoch 13/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1685 - accuracy: 0.9720 - val_loss: 642.0711 - val_accuracy: 0.4800
# Epoch 14/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.1686 - accuracy: 0.9520 - val_loss: 525.8832 - val_accuracy: 0.3800
# Epoch 15/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.0836 - accuracy: 0.9920 - val_loss: 531.5529 - val_accuracy: 0.3900
# Epoch 16/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1318 - accuracy: 0.9680 - val_loss: 1099.8671 - val_accuracy: 0.4000
# Epoch 17/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.3218 - accuracy: 0.9000 - val_loss: 714.1083 - val_accuracy: 0.4100
# Epoch 18/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1923 - accuracy: 0.9160 - val_loss: 513.1409 - val_accuracy: 0.3700
# Epoch 19/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.1077 - accuracy: 0.9640 - val_loss: 511.7123 - val_accuracy: 0.4300
# Epoch 20/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0794 - accuracy: 0.9760 - val_loss: 602.4661 - val_accuracy: 0.4300
# Epoch 21/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0359 - accuracy: 0.9880 - val_loss: 685.3812 - val_accuracy: 0.3900
# Epoch 22/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 618.5708 - val_accuracy: 0.4500
# Epoch 23/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 660.4936 - val_accuracy: 0.4300
# Epoch 24/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 680.4839 - val_accuracy: 0.4100
# Epoch 25/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 757.4509 - val_accuracy: 0.4100
# Epoch 26/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 823.4659 - val_accuracy: 0.3800
# Epoch 27/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 839.4496 - val_accuracy: 0.3800
# Epoch 28/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 831.5123 - val_accuracy: 0.4200
# Epoch 29/50
# 5/5 [==============================] - 12s 2s/step - loss: 8.4372e-04 - accuracy: 1.0000 - val_loss: 838.0359 - val_accuracy: 0.4600
# Epoch 30/50
# 5/5 [==============================] - 12s 2s/step - loss: 6.9099e-04 - accuracy: 1.0000 - val_loss: 850.9250 - val_accuracy: 0.4500
# Epoch 31/50
# 5/5 [==============================] - 14s 3s/step - loss: 5.9366e-04 - accuracy: 1.0000 - val_loss: 864.3131 - val_accuracy: 0.4400
# Epoch 32/50
# 5/5 [==============================] - 12s 2s/step - loss: 4.9401e-04 - accuracy: 1.0000 - val_loss: 882.5069 - val_accuracy: 0.4200
# Epoch 33/50
# 5/5 [==============================] - 13s 3s/step - loss: 4.0583e-04 - accuracy: 1.0000 - val_loss: 899.0914 - val_accuracy: 0.4100
# Epoch 34/50
# 5/5 [==============================] - 13s 2s/step - loss: 3.8321e-04 - accuracy: 1.0000 - val_loss: 910.1428 - val_accuracy: 0.4200
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 3.4627e-04 - accuracy: 1.0000 - val_loss: 913.2687 - val_accuracy: 0.4100
# Epoch 36/50
# 5/5 [==============================] - 12s 2s/step - loss: 3.1287e-04 - accuracy: 1.0000 - val_loss: 913.8391 - val_accuracy: 0.4100
# Epoch 37/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.8161e-04 - accuracy: 1.0000 - val_loss: 911.5491 - val_accuracy: 0.4100
# Epoch 38/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.5775e-04 - accuracy: 1.0000 - val_loss: 908.9325 - val_accuracy: 0.4200
# Epoch 39/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.4113e-04 - accuracy: 1.0000 - val_loss: 912.0942 - val_accuracy: 0.4200
# Epoch 40/50
# 5/5 [==============================] - 14s 3s/step - loss: 2.2467e-04 - accuracy: 1.0000 - val_loss: 916.8690 - val_accuracy: 0.4200
# Epoch 41/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.0533e-04 - accuracy: 1.0000 - val_loss: 926.4385 - val_accuracy: 0.4300
# Epoch 42/50
# 5/5 [==============================] - 13s 3s/step - loss: 1.8848e-04 - accuracy: 1.0000 - val_loss: 938.5547 - val_accuracy: 0.4300
# Epoch 43/50
# 5/5 [==============================] - 13s 3s/step - loss: 1.7376e-04 - accuracy: 1.0000 - val_loss: 970.3599 - val_accuracy: 0.4200
# Epoch 44/50
# 5/5 [==============================] - 18s 4s/step - loss: 1.5490e-04 - accuracy: 1.0000 - val_loss: 991.7509 - val_accuracy: 0.4100
# Epoch 45/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.5241e-04 - accuracy: 1.0000 - val_loss: 969.8444 - val_accuracy: 0.4100
# Epoch 46/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.3984e-04 - accuracy: 1.0000 - val_loss: 947.2509 - val_accuracy: 0.4100
# Epoch 47/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.3865e-04 - accuracy: 1.0000 - val_loss: 954.1308 - val_accuracy: 0.4200
# Epoch 48/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.2530e-04 - accuracy: 1.0000 - val_loss: 977.7355 - val_accuracy: 0.4100
# Epoch 49/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0750e-04 - accuracy: 1.0000 - val_loss: 1035.9122 - val_accuracy: 0.4000
# Epoch 50/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0687e-04 - accuracy: 1.0000 - val_loss: 1014.1916 - val_accuracy: 0.4000
# Test loss     : 1004.3582763671875
# Test accuracy : 0.47999998927116394

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
np.round(model.predict(Xtest))
